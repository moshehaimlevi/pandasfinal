# %% [markdown]
# <a href="https://colab.research.google.com/github/moshehaimlevi/pandasfinal/blob/main/hwprepd2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from IPython.display import display
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
file_path = '/content/drive/My Drive/books_sales.csv'
df_books_sales = pd.read_csv(file_path)
display(df_books_sales)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      sale_date  book_id  sale_price                   store_name
# 0   20/04/2024    12863       39.37               Marshall-Moore
# 1   01/08/2024    12863       76.76                    Price Ltd
# 2   30/12/2023    12863       13.97                Jenkins-Munoz
# 3   31/05/2024    14187       76.16             Jackson and Sons
# 4   26/04/2023    14187       45.11                 Clark-Walker
# ..         ...      ...         ...                          ...
# 95  08/10/2024    92659       40.21  Mayer, Knight and Patterson
# 96  25/01/2025    92659       52.49                     Dean Inc
# 97  21/07/2023    92659       37.52                    Green PLC
# 98  01/03/2024    92800       94.52                     Hill PLC
# 99  17/03/2024    96580       96.24     Casey, Benson and Morgan
#
# [100 rows x 4 columns]

# %%
import numpy as np
from IPython.display import display
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
file_path = '/content/drive/My Drive/books.csv'
df_books = pd.read_csv(file_path)
display(df_books)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#     book_id             author_name                                   title  \
# 0     82471             Justin Cook                      Rise of the Fallen
# 1     48525            Teresa Olson                         Dreams of Steel
# 2     85837           Cindy Hickman                    Memories of Tomorrow
# 3     91385            Theresa Shaw                     Secrets of the Mind
# 4     39428             James White                         Shadows of Time
# 5     54092            Leah Jackson                         Winds of Change
# 6     29735            Andrea Davis                         The Last Empire
# 7     87992     Dr. Heather Aguirre                       The Final Chapter
# 8     92222       Teresa Mclaughlin                      Rise of the Fallen
# 9     17977         Philip Cummings                    A Tale of Two Cities
# ...

# %%
df_books["catalog_number"].value_counts().sort_values(ascending=False)
# Out:
# catalog_number
# CAT-2008    2
# CAT-2007    2
# CAT-2006    2
# CAT-2005    2
# CAT-2004    2
# CAT-2003    2
# CAT-2002    2
# CAT-2001    2
# CAT-1008    1
# CAT-1007    1
# CAT-1006    1
# CAT-1005    1
# CAT-1004    1
# CAT-1003    1
# CAT-1002    1
# CAT-1001    1
# CAT-1009    1
# CAT-1010    1
# CAT-1011    1
# CAT-1012    1
# CAT-1013    1
# CAT-1014    1
# CAT-1015    1
# CAT-1016    1
# CAT-1024    1
# CAT-1023    1
# CAT-1022    1
# CAT-1021    1
# CAT-1020    1
# CAT-1019    1
# CAT-1018    1
# CAT-1017    1
# CAT-1032    1
# CAT-1031    1
# CAT-1030    1
# CAT-1029    1
# CAT-1028    1
# CAT-1027    1
# CAT-1026    1
# CAT-1025    1
# Name: count, dtype: int64

# %%
display(df_books[df_books['catalog_number'].duplicated(keep=False)].sort_values('catalog_number'))
# Out:
#     book_id        author_name                                   title  \
# 32    53783                NaN                           Broken Chains
# 33    20274        James Mejia         Broken Chains - Special Edition
# 34    50753  Tiffany Davenport                            Paths Unseen
# 35    58871  Tiffany Davenport                                     NaN
# 36    86910   Timothy Trujillo                        The Hidden Truth
# 37    77386   Timothy Trujillo      The Hidden Truth - Special Edition
# 38    58633                NaN                                     NaN
# 39    44065       Victor Burke   The Edge of Reality - Special Edition
# 40    45824                NaN                         Winds of Change
# 41    87457      Tiffany Mcgee       Winds of Change - Special Edition
# 42    46818       Jared Thomas                                     NaN
# 43    26735       Jared Thomas    Voices in the Dark - Special Edition
# ...

# %%
df_books['non_nan_count'] = df_books.notna().sum(axis=1)

df_books.sort_values(['catalog_number', 'non_nan_count'], ascending=[True, False], inplace=True)

duplicates = df_books[df_books['catalog_number'].duplicated(keep=False)]
display(duplicates)
# Out:
#     book_id        author_name                                   title  \
# 33    20274        James Mejia         Broken Chains - Special Edition
# 32    53783                NaN                           Broken Chains
# 34    50753  Tiffany Davenport                            Paths Unseen
# 35    58871  Tiffany Davenport                                     NaN
# 37    77386   Timothy Trujillo      The Hidden Truth - Special Edition
# 36    86910   Timothy Trujillo                        The Hidden Truth
# 39    44065       Victor Burke   The Edge of Reality - Special Edition
# 38    58633                NaN                                     NaN
# 41    87457      Tiffany Mcgee       Winds of Change - Special Edition
# 40    45824                NaN                         Winds of Change
# 43    26735       Jared Thomas    Voices in the Dark - Special Edition
# 42    46818       Jared Thomas                                     NaN
# ...

# %%
kept = duplicates.drop_duplicates(subset=['catalog_number'], keep='first')
removed = duplicates[~duplicates['catalog_number'].isin(kept['catalog_number'])]
display(removed)
display(kept)

duplicates.drop_duplicates(subset=['catalog_number'], keep='first', inplace=True)
df_books_remove = df_books[~df_books['catalog_number'].isin(removed['catalog_number'])]
display(df_books_remove)
# Out:
# Empty DataFrame
# Columns: [book_id, author_name, title, publication_year, catalog_number, non_nan_count]
# Index: []
#     book_id        author_name                                   title  \
# 33    20274        James Mejia         Broken Chains - Special Edition
# 34    50753  Tiffany Davenport                            Paths Unseen
# 37    77386   Timothy Trujillo      The Hidden Truth - Special Edition
# 39    44065       Victor Burke   The Edge of Reality - Special Edition
# 41    87457      Tiffany Mcgee       Winds of Change - Special Edition
# 43    26735       Jared Thomas    Voices in the Dark - Special Edition
# 45    39188     Brendan Mosley  Memories of Tomorrow - Special Edition
# 46    38900         Ryan Banks                          River of Stars
#
#     publication_year catalog_number  non_nan_count
# 33            1982.0       CAT-2001              5
# 34            2009.0       CAT-2002              5
# 37            1983.0       CAT-2003              5
# ...

# %%
df_books = pd.read_csv(file_path)
df_books_sales = pd.read_csv(file_path)

df_books.sort_values('book_id', inplace=True)

df_books["book_id"] = df_books["book_id"].replace({1: 2})

merged = removed.merge(kept, how='inner', on='book_id', suffixes=('_removed', '_kept'))

dict_replace = dict(zip(merged['book_id'], merged['book_id']))

df_books["book_id"] = df_books["book_id"].replace(dict_replace)

display(df_books)
# Out:
#     book_id             author_name                                   title  \
# 13    12863           Kevin Montoya                         Dreams of Steel
# 26    14187         Joshua Harrison                      Voices in the Dark
# 16    14352       John Alvarado DDS                     The Edge of Reality
# 9     17977         Philip Cummings                    A Tale of Two Cities
# 15    19799  Mrs. Cathy Gallegos MD                     Secrets of the Mind
# 33    20274             James Mejia         Broken Chains - Special Edition
# 19    25610            Ricky Graham                    Whispers of the Past
# 43    26735            Jared Thomas    Voices in the Dark - Special Edition
# 31    27691             Aaron Jones                     The Edge of Reality
# 6     29735            Andrea Davis                         The Last Empire
# 30    36854          Lindsay Valdez                    Whispers of the Past
# ...
